# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv(r"D:\amazon sales\sql\amazon_sales_clean.csv")

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       1611 non-null   str
#  1   Order Date     1611 non-null   str
#  2   Ship Date      1611 non-null   str
#  3   EmailID        1611 non-null   str
#  4   Geography      1611 non-null   str
#  5   Category       1611 non-null   str
#  6   Product Name   1611 non-null   str
#  7   Sales          1611 non-null   float64
#  8   Quantity       1611 non-null   float64
#  9   Profit         1611 non-null   float64
#  10  Shipping Days  1611 non-null   float64
#  11  Profit Margin  1611 non-null   float64
#  12  Month          1611 non-null   float64
#  13  year           1611 non-null   float64
# dtypes: float64(7), str(7)
# memory usage: 350.5 KB
# None

# %%
print(df.describe())
# Out:
#              Sales     Quantity       Profit  Shipping Days  Profit Margin  \
# count  1611.000000  1611.000000  1611.000000    1611.000000    1611.000000
# mean    206.358653     3.816884    29.435512       3.931099      22.587271
# std     404.194954     2.250049   104.878109       1.776547      26.898376
# min       0.990000     1.000000  -938.280000       0.000000    -210.000000
# 25%      17.235000     2.000000     3.585000       3.000000      10.000000
# 50%      56.300000     3.000000    10.180000       4.000000      29.000000
# 75%     204.290000     5.000000    30.985000       5.000000      37.500000
# max    4476.800000    14.000000  1379.980000       7.000000      50.000000
#
#              Month         year
# count  1611.000000  1611.000000
# mean      7.871508  2012.737430
# std       3.284672     1.120097
# min       1.000000  2011.000000
# 25%       5.000000  2012.000000
# 50%       9.000000  2013.000000
# 75%      11.000000  2014.000000
# max      12.000000  2014.000000

# %%
print(df.isnull().sum())
# Out:
# Order ID         1592
# Order Date       1592
# Ship Date        1592
# EmailID          1592
# Geography        1592
# Category         1592
# Product Name     1592
# Sales            1592
# Quantity         1592
# Profit           1592
# Shipping Days    1592
# Profit Margin    1592
# Month            1592
# year             1592
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 1591

# %%
print(df.groupby("Category")["Sales"].sum())
# Out:
# Category
# Accessories    26541.57
# Appliances     12788.89
# Art             5967.83
# Binders        25200.97
# Bookcases      22775.43
# Chairs         52765.66
# Copiers        18439.60
# Envelopes       2115.46
# Fasteners        525.08
# Furnishings    17813.38
# Labels          1533.36
# Machines       12878.42
# Paper          12246.74
# Phones         44671.78
# Storage        34158.36
# Supplies        2616.92
# Tables         39404.34
# Name: Sales, dtype: float64

# %%
print(df.groupby("Geography")["Sales"].sum())
# Out:
# Geography
# United States,Albuquerque,New Mexico     1413.44
# United States,Anaheim,California         4985.59
# United States,Antioch,California           19.44
# United States,Apple Valley,California     609.28
# United States,Arvada,Colorado              15.14
#                                           ...
# United States,Westminster,California      987.46
# United States,Whittier,California         444.77
# United States,Woodland,California         243.73
# United States,Yucaipa,California           50.80
# United States,Yuma,Arizona                840.88
# Name: Sales, Length: 170, dtype: float64
